# %% [markdown]
# <a href="https://colab.research.google.com/github/MithunChevakula/Data-Mining/blob/main/NLP_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
corpus = ['data science is one of the most important fields of science', 'this is one of the best data science courses',
'data scientists analyze data' ]

# %%
words_set = set()
for doc in corpus:
  words = doc.split(' ')
  words_set = words_set.union(set(words))

print('Number of words in the corpus:',len(words_set))
print('The words in the corpus: \n', words_set)
# Out:
# Number of words in the corpus: 14
# The words in the corpus:
#  {'courses', 'scientists', 'most', 'fields', 'science', 'one', 'data', 'of', 'analyze', 'best', 'important', 'this', 'is', 'the'}

# %%
n_docs = len(corpus)
n_words_set = len(words_set)
words_list=list(words_set)
df_tf = pd.DataFrame(np.zeros((n_docs, n_words_set)), columns=words_list)
for i in range(n_docs):
  words = corpus[i].split(' ')
  for w in words:
    df_tf[w][i] = df_tf[w][i] + (1 / len(words))

df_tf
# Out:
#     courses  scientists      most    fields   science       one      data  \
# 0  0.000000        0.00  0.090909  0.090909  0.181818  0.090909  0.090909
# 1  0.111111        0.00  0.000000  0.000000  0.111111  0.111111  0.111111
# 2  0.000000        0.25  0.000000  0.000000  0.000000  0.000000  0.500000
#
#          of  analyze      best  important      this        is       the
# 0  0.181818     0.00  0.000000   0.090909  0.000000  0.090909  0.090909
# 1  0.111111     0.00  0.111111   0.000000  0.111111  0.111111  0.111111
# 2  0.000000     0.25  0.000000   0.000000  0.000000  0.000000  0.000000

# %%
print("IDF of: ")

idf = {}

for w in words_set:
  k = 0
  for i in range(n_docs):
    if w in corpus[i].split():
      k += 1
      idf[w] = np.log10(n_docs / k)
      print(f'{w:>15}: {idf[w]:>10}' )
# Out:
# IDF of:
#         courses: 0.47712125471966244
#      scientists: 0.47712125471966244
#            most: 0.47712125471966244
#          fields: 0.47712125471966244
#         science: 0.47712125471966244
#         science: 0.17609125905568124
#             one: 0.47712125471966244
#             one: 0.17609125905568124
#            data: 0.47712125471966244
#            data: 0.17609125905568124
#            data:        0.0
#              of: 0.47712125471966244
#              of: 0.17609125905568124
#         analyze: 0.47712125471966244
#            best: 0.47712125471966244
#       important: 0.47712125471966244
#            this: 0.47712125471966244
#              is: 0.47712125471966244
#              is: 0.17609125905568124
#             the: 0.47712125471966244
#             the: 0.17609125905568124

# %%
df_tf_idf = df_tf.copy()

for w in words_set:
  for i in range(n_docs):
    df_tf_idf[w][i] = df_tf[w][i] * idf[w]
df_tf_idf
# Out:
#     courses  scientists      most    fields   science       one  data  \
# 0  0.000000     0.00000  0.043375  0.043375  0.032017  0.016008   0.0
# 1  0.053013     0.00000  0.000000  0.000000  0.019566  0.019566   0.0
# 2  0.000000     0.11928  0.000000  0.000000  0.000000  0.000000   0.0
#
#          of  analyze      best  important      this        is       the
# 0  0.032017  0.00000  0.000000   0.043375  0.000000  0.016008  0.016008
# 1  0.019566  0.00000  0.053013   0.000000  0.053013  0.019566  0.019566
# 2  0.000000  0.11928  0.000000   0.000000  0.000000  0.000000  0.000000
